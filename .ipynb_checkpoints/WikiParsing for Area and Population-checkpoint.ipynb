# %%
import pandas as pd
import numpy as np

# %%
countries_codes = pd.DataFrame.from_csv(r"c:\Dev\05. Jupyter\2. FDA countries clean\csv\countries_codes_curated_1Nov.csv")
countries_codes.head()
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   """Entry point for launching an IPython kernel.
#                iso2 full_country_name  comment  \
# 0  no_code_**none**          **None**      NaN
# 1                af       Afghanistan      NaN
# 2                al           Albania      NaN
# 3                dz           Algeria      NaN
# 4                as    American Samoa      NaN
#
#                                    wiki_link  population  area
# 0                                        NaN           1     1
# 1  https://en.wikipedia.org/wiki/Afghanistan           1     1
# 2      https://en.wikipedia.org/wiki/Albania           1     1
# 3      https://en.wikipedia.org/wiki/Algeria           1     1
# 4                                        NaN           1     1

# %%
from bs4 import BeautifulSoup
import requests
import logging, hashlib, time, os, os.path, codecs

logging.basicConfig(filename=r'c:\Dev\04. Python\04. Sqlite converter for FDA list\main.log',level=logging.DEBUG)


def getPage(page_url, BASE_PATH, time_to_sleep_before_network = 10):
    logging.debug("Page URL:{}".format(page_url))
    print(page_url)
    
    file_to_save = BASE_PATH+  \
                        page_url.replace("/", "_").replace("?", "_").replace(":", "_")[:50]+ \
                        "_"+hashlib.sha224(page_url.encode('utf-8')).hexdigest()+ \
                        ".html"
    logging.debug("File name:{}".format(file_to_save.encode("utf-8")))
    if os.path.exists(file_to_save):
        logging.debug("File exists returning from disk")
        f=codecs.open(file_to_save, "r", encoding="utf-8")
        r = f.read()
        f.close()
        return r

    logging.debug("File does not exist: downloading")
    print("File does not exist: downloading")
    time.sleep(time_to_sleep_before_network)
    print("Sleep over")
    r = requests.get(page_url)
    #https://stackoverflow.com/questions/934160/write-to-utf-8-file-in-python
    f = codecs.open(file_to_save, "w", "utf-8")
    f.write(r.text)
    f.close()
    return r.text

# %%
import re


def parsePageForArea(pageLink):
    page_content = getPage(pageLink, "c:\\Dev\\05. Jupyter\\2. FDA countries clean\\", 10)

    soup = BeautifulSoup(page_content)

    # infobox = soup.select(".infobox")
    # print(infobox)
    rows = soup.select(".infobox")
    # print(rows)
    # print(type(rows))
    for row in rows[0].find_all("tr"):
    #     print(row)
        link = row.select("th a")
        if len(link)>0:
            if link[0].text.strip().lower() == "area":
                print(link)
                print(link[0].parent.parent.next_sibling)

                area_text =  link[0].parent.parent.next_sibling.select("td")[0].text
                print(area_text)

                matchObj = re.search( r'([\d,]{1,})', area_text)#, re.M|re.I)

                if matchObj:
                    print("matchObj.group() :{} ".format(matchObj.group()))
                    print("matchObj.group(0) :{} ".format(matchObj.group(0))) 
                    print("matchObj.group(1) :{} ".format(matchObj.group(1)))
                    return int(matchObj.group().replace(",", ""))
    #                print("matchObj.group() :{} ".format(matchObj.group(2)))     
                else:
                    print("No match!!")
                    return -1

# %%
result_areas_array = []
# for country in countries_codes.loc[countries_codes["wiki_link"].isnull()==False].values:
for country in countries_codes.values:
    print(country)
    if type(country[3]) is float:
        result_areas_array.append(-1)
    else:
        link = country[3]
        print(link)
        areaResult = parsePageForArea(link)
        result_areas_array.append(areaResult)
        print(areaResult)
# Out:
# ['no_code_**none**' '**None**' nan nan 1 -1]
# ['af' 'Afghanistan' nan 'https://en.wikipedia.org/wiki/Afghanistan' 1 100]
# https://en.wikipedia.org/wiki/Afghanistan
# https://en.wikipedia.org/wiki/Afghanistan
# [<a href="/wiki/Geography_of_Afghanistan" title="Geography of Afghanistan">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 652,864<sup class="reference" id="cite_ref-Area_and_administrative_Population_6-0"><a href="#cite_note-Area_and_administrative_Population-6">[5]</a></sup> km<sup>2</sup> (252,072 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">40th</a>)</td></tr>
#
# 652,864[5] km2 (252,072 sq mi) (40th)
# matchObj.group() :652,864
# matchObj.group(0) :652,864
# matchObj.group(1) :652,864
# 652864
# ['al' 'Albania' nan 'https://en.wikipedia.org/wiki/Albania' 1 100]
# https://en.wikipedia.org/wiki/Albania
# https://en.wikipedia.org/wiki/Albania
# [<a href="/wiki/Geography_of_Albania" title="Geography of Albania">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 28,748 km<sup>2</sup> (11,100 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">140th</a>)</td></tr>
#
# 28,748 km2 (11,100 sq mi) (140th)
# matchObj.group() :28,748
# matchObj.group(0) :28,748
# matchObj.group(1) :28,748
# 28748
# ['dz' 'Algeria' nan 'https://en.wikipedia.org/wiki/Algeria' 1 100]
# https://en.wikipedia.org/wiki/Algeria
# https://en.wikipedia.org/wiki/Algeria
# [<a href="/wiki/Geography_of_Algeria" title="Geography of Algeria">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 2,381,741 km<sup>2</sup> (919,595 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">10th</a>)</td></tr>
#
# 2,381,741 km2 (919,595 sq mi) (10th)
# matchObj.group() :2,381,741
# matchObj.group(0) :2,381,741
# matchObj.group(1) :2,381,741
# 2381741
# ['as' 'American Samoa' nan nan 1 -1]
# ['ad' 'Andorra' nan 'https://en.wikipedia.org/wiki/Andorra' 1 100]
# https://en.wikipedia.org/wiki/Andorra
# https://en.wikipedia.org/wiki/Andorra
# [<a href="/wiki/Geography_of_Andorra" title="Geography of Andorra">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 467.63 km<sup>2</sup> (180.55 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">180th</a>)</td></tr>
#
# 467.63 km2 (180.55 sq mi) (180th)
# matchObj.group() :467
# matchObj.group(0) :467
# matchObj.group(1) :467
# 467
# ['ao' 'Angola' nan 'https://en.wikipedia.org/wiki/Angola' 1 100]
# https://en.wikipedia.org/wiki/Angola
# https://en.wikipedia.org/wiki/Angola
# [<a href="/wiki/Geography_of_Angola" title="Geography of Angola">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 1,246,700 km<sup>2</sup> (481,400 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">22nd</a>)</td></tr>
#
# 1,246,700 km2 (481,400 sq mi) (22nd)
# matchObj.group() :1,246,700
# matchObj.group(0) :1,246,700
# matchObj.group(1) :1,246,700
# 1246700
# ['ar' 'Argentina' nan nan 1 -1]
# ['am' 'Armenia' nan 'https://en.wikipedia.org/wiki/Armenia' 1 100]
# https://en.wikipedia.org/wiki/Armenia
# https://en.wikipedia.org/wiki/Armenia
# [<a href="/wiki/Geography_of_Armenia" title="Geography of Armenia">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 29,743 km<sup>2</sup> (11,484 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">138th</a>)</td></tr>
#
# 29,743 km2 (11,484 sq mi) (138th)
# matchObj.group() :29,743
# matchObj.group(0) :29,743
# matchObj.group(1) :29,743
# 29743
# ['aw' 'Aruba' nan nan 1 -1]
# ['au' 'Australia' nan 'https://en.wikipedia.org/wiki/Australia' 1 100]
# https://en.wikipedia.org/wiki/Australia
# https://en.wikipedia.org/wiki/Australia
# [<a href="/wiki/Geography_of_Australia" title="Geography of Australia">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 7,692,024 km<sup>2</sup> (2,969,907 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">6th</a>)</td></tr>
#
# 7,692,024 km2 (2,969,907 sq mi) (6th)
# matchObj.group() :7,692,024
# matchObj.group(0) :7,692,024
# matchObj.group(1) :7,692,024
# 7692024
# ['at' 'Austria' nan 'https://en.wikipedia.org/wiki/Austria' 1 100]
# https://en.wikipedia.org/wiki/Austria
# https://en.wikipedia.org/wiki/Austria
# [<a href="/wiki/Geography_of_Austria" title="Geography of Austria">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 83,879 km<sup>2</sup> (32,386 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">113th</a>)</td></tr>
#
# 83,879 km2 (32,386 sq mi) (113th)
# matchObj.group() :83,879
# matchObj.group(0) :83,879
# matchObj.group(1) :83,879
# 83879
# ['az' 'Azerbaijan' nan 'https://en.wikipedia.org/wiki/Azerbaijan' 1 100]
# https://en.wikipedia.org/wiki/Azerbaijan
# https://en.wikipedia.org/wiki/Azerbaijan
# [<a href="/wiki/Geography_of_Azerbaijan" title="Geography of Azerbaijan">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 86,600 km<sup>2</sup> (33,400 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">111th</a>)</td></tr>
#
# 86,600 km2 (33,400 sq mi) (111th)
# matchObj.group() :86,600
# matchObj.group(0) :86,600
# matchObj.group(1) :86,600
# 86600
# ['bs' 'Bahamas' nan nan 1 -1]
# ['bh' 'Bahrain' nan 'https://en.wikipedia.org/wiki/Bahrain' 1 100]
# https://en.wikipedia.org/wiki/Bahrain
# https://en.wikipedia.org/wiki/Bahrain
# [<a href="/wiki/Geography_of_Bahrain" title="Geography of Bahrain">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 765.3 km<sup>2</sup> (295.5 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">173rd</a>)</td></tr>
#
# 765.3 km2 (295.5 sq mi) (173rd)
# matchObj.group() :765
# matchObj.group(0) :765
# matchObj.group(1) :765
# 765
# ['bd' 'Bangladesh' nan 'https://en.wikipedia.org/wiki/Bangladesh' 1 100]
# https://en.wikipedia.org/wiki/Bangladesh
# https://en.wikipedia.org/wiki/Bangladesh
# [<a href="/wiki/Geography_of_Bangladesh" title="Geography of Bangladesh">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 147,570<sup class="reference" id="cite_ref-5"><a href="#cite_note-5">[5]</a></sup> km<sup>2</sup> (56,980 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">92nd</a>)</td></tr>
#
# 147,570[5] km2 (56,980 sq mi) (92nd)
# matchObj.group() :147,570
# matchObj.group(0) :147,570
# matchObj.group(1) :147,570
# 147570
# ['bb' 'Barbados' nan 'https://en.wikipedia.org/wiki/Barbados' 1 100]
# https://en.wikipedia.org/wiki/Barbados
# https://en.wikipedia.org/wiki/Barbados
# [<a href="/wiki/Geography_of_Barbados" title="Geography of Barbados">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 439 km<sup>2</sup> (169 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">183rd</a>)</td></tr>
#
# 439 km2 (169 sq mi) (183rd)
# matchObj.group() :439
# matchObj.group(0) :439
# matchObj.group(1) :439
# 439
# ['by' 'Belarus' nan 'https://en.wikipedia.org/wiki/Belarus' 1 100]
# https://en.wikipedia.org/wiki/Belarus
# https://en.wikipedia.org/wiki/Belarus
# [<a href="/wiki/Geography_of_Belarus" title="Geography of Belarus">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 207,595 km<sup>2</sup> (80,153 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">84th</a>)</td></tr>
#
# 207,595 km2 (80,153 sq mi) (84th)
# matchObj.group() :207,595
# matchObj.group(0) :207,595
# matchObj.group(1) :207,595
# 207595
# ['be' 'Belgium' nan 'https://en.wikipedia.org/wiki/Belgium' 1 100]
# https://en.wikipedia.org/wiki/Belgium
# https://en.wikipedia.org/wiki/Belgium
# [<a href="/wiki/Geography_of_Belgium" title="Geography of Belgium">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 30,528 km<sup>2</sup> (11,787 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">136th</a>)</td></tr>
#
# 30,528 km2 (11,787 sq mi) (136th)
# matchObj.group() :30,528
# matchObj.group(0) :30,528
# matchObj.group(1) :30,528
# 30528
# ['bz' 'Belize' nan 'https://en.wikipedia.org/wiki/Belize' 1 100]
# https://en.wikipedia.org/wiki/Belize
# https://en.wikipedia.org/wiki/Belize
# [<a href="/wiki/Geography_of_Belize" title="Geography of Belize">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 22,966 km<sup>2</sup> (8,867 sq mi)<sup class="reference" id="cite_ref-cia_1-1"><a href="#cite_note-cia-1">[1]</a></sup><sup class="reference" id="cite_ref-censusarea_3-0"><a href="#cite_note-censusarea-3">[2]</a></sup> (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">147th</a>)</td></tr>
#
# 22,966 km2 (8,867 sq mi)[1][2] (147th)
# matchObj.group() :22,966
# matchObj.group(0) :22,966
# matchObj.group(1) :22,966
# 22966
# ['bj' 'Benin' nan 'https://en.wikipedia.org/wiki/Benin' 1 100]
# https://en.wikipedia.org/wiki/Benin
# https://en.wikipedia.org/wiki/Benin
# [<a href="/wiki/Geography_of_Benin" title="Geography of Benin">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 114,763 km<sup>2</sup> (44,310 sq mi)<sup class="reference" id="cite_ref-AS2010_1-0"><a href="#cite_note-AS2010-1">[1]</a></sup> (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">100th</a>)</td></tr>
#
# 114,763 km2 (44,310 sq mi)[1] (100th)
# matchObj.group() :114,763
# matchObj.group(0) :114,763
# matchObj.group(1) :114,763
# 114763
# ['bm' 'Bermuda' nan nan 1 -1]
# ['bt' 'Bhutan' nan 'https://en.wikipedia.org/wiki/Bhutan' 1 100]
# https://en.wikipedia.org/wiki/Bhutan
# https://en.wikipedia.org/wiki/Bhutan
# [<a href="/wiki/Geography_of_Bhutan" title="Geography of Bhutan">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 38,394 km<sup>2</sup> (14,824 sq mi)<sup class="reference" id="cite_ref-FYP9_1-0"><a href="#cite_note-FYP9-1">[1]</a></sup><sup class="reference" id="cite_ref-official_2-0"><a href="#cite_note-official-2">[2]</a></sup> (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">133rd</a>)</td></tr>
#
# 38,394 km2 (14,824 sq mi)[1][2] (133rd)
# matchObj.group() :38,394
# matchObj.group(0) :38,394
# matchObj.group(1) :38,394
# 38394
# ['bo' 'Bolivia' nan 'https://en.wikipedia.org/wiki/Bolivia' 1 100]
# https://en.wikipedia.org/wiki/Bolivia
# https://en.wikipedia.org/wiki/Bolivia
# [<a href="/wiki/Geography_of_Bolivia" title="Geography of Bolivia">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 1,098,581 km<sup>2</sup> (424,164 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">27th</a>)</td></tr>
#
# 1,098,581 km2 (424,164 sq mi) (27th)
# matchObj.group() :1,098,581
# matchObj.group(0) :1,098,581
# matchObj.group(1) :1,098,581
# 1098581
# ['ba' 'Bosnia and Herzegovina' nan
#  'https://en.wikipedia.org/wiki/Bosnia_and_Herzegovina' 1 100]
# https://en.wikipedia.org/wiki/Bosnia_and_Herzegovina
# https://en.wikipedia.org/wiki/Bosnia_and_Herzegovina
# [<a href="/wiki/Geography_of_Bosnia_and_Herzegovina" title="Geography of Bosnia and Herzegovina">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 51,129 km<sup>2</sup> (19,741 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">125th</a>)</td></tr>
#
# 51,129 km2 (19,741 sq mi) (125th)
# matchObj.group() :51,129
# matchObj.group(0) :51,129
# matchObj.group(1) :51,129
# 51129
# ['bw' 'Botswana' nan 'https://en.wikipedia.org/wiki/Botswana' 1 100]
# https://en.wikipedia.org/wiki/Botswana
# https://en.wikipedia.org/wiki/Botswana
# [<a href="/wiki/Geography_of_Botswana" title="Geography of Botswana">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 581,730 km<sup>2</sup> (224,610 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">47th</a>)</td></tr>
#
# 581,730 km2 (224,610 sq mi) (47th)
# matchObj.group() :581,730
# matchObj.group(0) :581,730
# matchObj.group(1) :581,730
# 581730
# ['br' 'Brazil' nan 'https://en.wikipedia.org/wiki/Brazil' 1 100]
# https://en.wikipedia.org/wiki/Brazil
# https://en.wikipedia.org/wiki/Brazil
# [<a href="/wiki/Geography_of_Brazil" title="Geography of Brazil">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 8,515,767 km<sup>2</sup> (3,287,956 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">5th</a>)</td></tr>
#
# 8,515,767 km2 (3,287,956 sq mi) (5th)
# matchObj.group() :8,515,767
# matchObj.group(0) :8,515,767
# matchObj.group(1) :8,515,767
# 8515767
# ['bn' 'Brunei Darussalam' nan 'https://en.wikipedia.org/wiki/Brunei' 1 100]
# https://en.wikipedia.org/wiki/Brunei
# https://en.wikipedia.org/wiki/Brunei
# [<a href="/wiki/Geography_of_Brunei" title="Geography of Brunei">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 5,765 km<sup>2</sup> (2,226 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">164th</a>)</td></tr>
#
# 5,765 km2 (2,226 sq mi) (164th)
# matchObj.group() :5,765
# matchObj.group(0) :5,765
# matchObj.group(1) :5,765
# 5765
# ['bg' 'Bulgaria' nan 'https://en.wikipedia.org/wiki/Bulgaria' 1 100]
# https://en.wikipedia.org/wiki/Bulgaria
# https://en.wikipedia.org/wiki/Bulgaria
# [<a href="/wiki/Geography_of_Bulgaria" title="Geography of Bulgaria">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 110,993.6<sup class="reference" id="cite_ref-Penin_4-0"><a href="#cite_note-Penin-4">[1]</a></sup> km<sup>2</sup> (42,854.9 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">103rd</a>)</td></tr>
#
# 110,993.6[1] km2 (42,854.9 sq mi) (103rd)
# matchObj.group() :110,993
# matchObj.group(0) :110,993
# matchObj.group(1) :110,993
# 110993
# ['bf' 'Burkina Faso' nan 'https://en.wikipedia.org/wiki/Burkina_Faso' 1
#  100]
# https://en.wikipedia.org/wiki/Burkina_Faso
# https://en.wikipedia.org/wiki/Burkina_Faso
# [<a href="/wiki/Geography_of_Burkina_Faso" title="Geography of Burkina Faso">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 274,200 km<sup>2</sup> (105,900 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">74th</a>)</td></tr>
#
# 274,200 km2 (105,900 sq mi) (74th)
# matchObj.group() :274,200
# matchObj.group(0) :274,200
# matchObj.group(1) :274,200
# 274200
# ['bi' 'Burundi' nan 'https://en.wikipedia.org/wiki/Burundi' 1 100]
# https://en.wikipedia.org/wiki/Burundi
# https://en.wikipedia.org/wiki/Burundi
# [<a href="/wiki/Geography_of_Burundi" title="Geography of Burundi">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 27,834 km<sup>2</sup> (10,747 sq mi)<sup class="reference" id="cite_ref-ISTEEBU_7-0"><a href="#cite_note-ISTEEBU-7">[7]</a></sup> (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">142nd</a>)</td></tr>
#
# 27,834 km2 (10,747 sq mi)[7] (142nd)
# matchObj.group() :27,834
# matchObj.group(0) :27,834
# matchObj.group(1) :27,834
# 27834
# ['kh' 'Cambodia' nan 'https://en.wikipedia.org/wiki/Cambodia' 1 100]
# https://en.wikipedia.org/wiki/Cambodia
# https://en.wikipedia.org/wiki/Cambodia
# [<a href="/wiki/Geography_of_Cambodia" title="Geography of Cambodia">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 181,035 km<sup>2</sup> (69,898 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">88th</a>)</td></tr>
#
# 181,035 km2 (69,898 sq mi) (88th)
# matchObj.group() :181,035
# matchObj.group(0) :181,035
# matchObj.group(1) :181,035
# 181035
# ['cm' 'Cameroon' nan 'https://en.wikipedia.org/wiki/Cameroon' 1 100]
# https://en.wikipedia.org/wiki/Cameroon
# https://en.wikipedia.org/wiki/Cameroon
# [<a href="/wiki/Geography_of_Cameroon" title="Geography of Cameroon">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 475,442 km<sup>2</sup> (183,569 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">53rd</a>)</td></tr>
#
# 475,442 km2 (183,569 sq mi) (53rd)
# matchObj.group() :475,442
# matchObj.group(0) :475,442
# matchObj.group(1) :475,442
# 475442
# ['ca' 'Canada' nan nan 1 -1]
# ['ky' 'Cayman Islands' nan nan 1 -1]
# ['cf' 'Central African Republic' nan
#  'https://en.wikipedia.org/wiki/Central_African_Republic' 1 100]
# https://en.wikipedia.org/wiki/Central_African_Republic
# https://en.wikipedia.org/wiki/Central_African_Republic
# [<a href="/wiki/Geography_of_the_Central_African_Republic" title="Geography of the Central African Republic">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 622,984 km<sup>2</sup> (240,535 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">44th</a>)</td></tr>
#
# 622,984 km2 (240,535 sq mi) (44th)
# matchObj.group() :622,984
# matchObj.group(0) :622,984
# matchObj.group(1) :622,984
# 622984
# ['td' 'Chad' nan 'https://en.wikipedia.org/wiki/Chad' 1 100]
# https://en.wikipedia.org/wiki/Chad
# https://en.wikipedia.org/wiki/Chad
# [<a href="/wiki/Geography_of_Chad" title="Geography of Chad">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 1,284,000 km<sup>2</sup> (496,000 sq mi)<sup class="reference" id="cite_ref-area_2-0"><a href="#cite_note-area-2">[2]</a></sup> (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">20th</a>)</td></tr>
#
# 1,284,000 km2 (496,000 sq mi)[2] (20th)
# matchObj.group() :1,284,000
# matchObj.group(0) :1,284,000
# matchObj.group(1) :1,284,000
# 1284000
# ['cl' 'Chile' nan 'https://en.wikipedia.org/wiki/Chile' 1 100]
# https://en.wikipedia.org/wiki/Chile
# https://en.wikipedia.org/wiki/Chile
# [<a href="/wiki/Geography_of_Chile" title="Geography of Chile">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 756,096.3<sup class="reference" id="cite_ref-ce2006_3-0"><a href="#cite_note-ce2006-3">[3]</a></sup> km<sup>2</sup> (291,930.4 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">37th</a>)</td></tr>
#
# 756,096.3[3] km2 (291,930.4 sq mi) (37th)
# matchObj.group() :756,096
# matchObj.group(0) :756,096
# matchObj.group(1) :756,096
# 756096
# ['cn' 'China' nan nan 1 -1]
# ['co' 'Colombia' nan 'https://en.wikipedia.org/wiki/Colombia' 1 100]
# https://en.wikipedia.org/wiki/Colombia
# https://en.wikipedia.org/wiki/Colombia
# [<a href="/wiki/Geography_of_Colombia" title="Geography of Colombia">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 1,141,748 km<sup>2</sup> (440,831 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">25th</a>)</td></tr>
#
# 1,141,748 km2 (440,831 sq mi) (25th)
# matchObj.group() :1,141,748
# matchObj.group(0) :1,141,748
# matchObj.group(1) :1,141,748
# 1141748
# ['km' 'Comoros' nan 'https://en.wikipedia.org/wiki/Comoros' 1 100]
# https://en.wikipedia.org/wiki/Comoros
# https://en.wikipedia.org/wiki/Comoros
# [<a class="mw-redirect" href="/wiki/Geography_of_Comoros" title="Geography of Comoros">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 1,862 km<sup>2</sup> (719 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">171th<sup>a</sup></a>)</td></tr>
#
# 1,862 km2 (719 sq mi) (171tha)
# matchObj.group() :1,862
# matchObj.group(0) :1,862
# matchObj.group(1) :1,862
# 1862
# ['cd' 'Congo' nan nan 1 -1]
# ['cr' 'Costa Rica' nan 'https://en.wikipedia.org/wiki/Costa_Rica' 1 100]
# https://en.wikipedia.org/wiki/Costa_Rica
# https://en.wikipedia.org/wiki/Costa_Rica
# [<a href="/wiki/Geography_of_Costa_Rica" title="Geography of Costa Rica">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 51,100 km<sup>2</sup> (19,700 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">126th</a>)</td></tr>
#
# 51,100 km2 (19,700 sq mi) (126th)
# matchObj.group() :51,100
# matchObj.group(0) :51,100
# matchObj.group(1) :51,100
# 51100
# ['hr' 'Croatia' nan 'https://en.wikipedia.org/wiki/Croatia' 1 100]
# https://en.wikipedia.org/wiki/Croatia
# https://en.wikipedia.org/wiki/Croatia
# [<a href="/wiki/Geography_of_Croatia" title="Geography of Croatia">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 56,594 km<sup>2</sup> (21,851 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">124th</a>)</td></tr>
#
# 56,594 km2 (21,851 sq mi) (124th)
# matchObj.group() :56,594
# matchObj.group(0) :56,594
# matchObj.group(1) :56,594
# 56594
# ['cu' 'Cuba' nan 'https://en.wikipedia.org/wiki/Cuba' 1 100]
# https://en.wikipedia.org/wiki/Cuba
# https://en.wikipedia.org/wiki/Cuba
# [<a href="/wiki/Geography_of_Cuba" title="Geography of Cuba">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 109,884 km<sup>2</sup> (42,426 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">104th</a>)</td></tr>
#
# 109,884 km2 (42,426 sq mi) (104th)
# matchObj.group() :109,884
# matchObj.group(0) :109,884
# matchObj.group(1) :109,884
# 109884
# ['cy' 'Cyprus' nan 'https://en.wikipedia.org/wiki/Cyprus' 1 100]
# https://en.wikipedia.org/wiki/Cyprus
# https://en.wikipedia.org/wiki/Cyprus
# [<a href="/wiki/Geography_of_Cyprus" title="Geography of Cyprus">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total<sup class="reference" id="cite_ref-island_5-0"><a href="#cite_note-island-5">[c]</a></sup></div></th><td>
# 9,251 km<sup>2</sup> (3,572 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">162nd</a>)</td></tr>
#
# 9,251 km2 (3,572 sq mi) (162nd)
# matchObj.group() :9,251
# matchObj.group(0) :9,251
# matchObj.group(1) :9,251
# 9251
# ['cz' 'Czechia' nan nan 1 -1]
# ['ci' "Côte D'Ivoire" nan nan 1 -1]
# ['dk' 'Denmark' nan 'https://en.wikipedia.org/wiki/Denmark' 1 100]
# https://en.wikipedia.org/wiki/Denmark
# https://en.wikipedia.org/wiki/Denmark
# [<a href="/wiki/Geography_of_Denmark" title="Geography of Denmark">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Metropolitan</div></th><td>
# 42,933 km<sup>2</sup> (16,577 sq mi)<sup class="reference" id="cite_ref-area_7-0"><a href="#cite_note-area-7">[3]</a></sup> (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">130th</a>)</td></tr>
#
# 42,933 km2 (16,577 sq mi)[3] (130th)
# matchObj.group() :42,933
# matchObj.group(0) :42,933
# matchObj.group(1) :42,933
# 42933
# ['dj' 'Djibouti' nan 'https://en.wikipedia.org/wiki/Djibouti' 1 100]
# https://en.wikipedia.org/wiki/Djibouti
# https://en.wikipedia.org/wiki/Djibouti
# [<a href="/wiki/Geography_of_Djibouti" title="Geography of Djibouti">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 23,200<sup class="reference" id="cite_ref-CIA_2-2"><a href="#cite_note-CIA-2">[2]</a></sup> km<sup>2</sup> (9,000 sq mi)<sup class="reference" id="cite_ref-CIA_2-3"><a href="#cite_note-CIA-2">[2]</a></sup> (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">146th</a>)</td></tr>
#
# 23,200[2] km2 (9,000 sq mi)[2] (146th)
# matchObj.group() :23,200
# matchObj.group(0) :23,200
# matchObj.group(1) :23,200
# 23200
# ['do' 'Dominican Republic' nan
#  'https://en.wikipedia.org/wiki/Dominican_Republic' 1 100]
# https://en.wikipedia.org/wiki/Dominican_Republic
# https://en.wikipedia.org/wiki/Dominican_Republic
# None
# ['ec' 'Ecuador' nan 'https://en.wikipedia.org/wiki/Ecuador' 1 100]
# https://en.wikipedia.org/wiki/Ecuador
# https://en.wikipedia.org/wiki/Ecuador
# [<a href="/wiki/Geography_of_Ecuador" title="Geography of Ecuador">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 283,561<sup class="reference" id="cite_ref-CIAfactbook_5-0"><a href="#cite_note-CIAfactbook-5">[5]</a></sup> km<sup>2</sup> (109,484 sq mi)<sup>a</sup> (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">73rd</a>)</td></tr>
#
# 283,561[5] km2 (109,484 sq mi)a (73rd)
# matchObj.group() :283,561
# matchObj.group(0) :283,561
# matchObj.group(1) :283,561
# 283561
# ['eg' 'Egypt' nan 'https://en.wikipedia.org/wiki/Egypt' 1 100]
# https://en.wikipedia.org/wiki/Egypt
# https://en.wikipedia.org/wiki/Egypt
# [<a href="/wiki/Geography_of_Egypt" title="Geography of Egypt">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 1,010,408<sup class="reference" id="cite_ref-4"><a href="#cite_note-4">[4]</a></sup> km<sup>2</sup> (390,121 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">29th</a>)</td></tr>
#
# 1,010,408[4] km2 (390,121 sq mi) (29th)
# matchObj.group() :1,010,408
# matchObj.group(0) :1,010,408
# matchObj.group(1) :1,010,408
# 1010408
# ['sv' 'El Salvador' nan 'https://en.wikipedia.org/wiki/El_Salvador' 1 100]
# https://en.wikipedia.org/wiki/El_Salvador
# https://en.wikipedia.org/wiki/El_Salvador
# [<a href="/wiki/Geography_of_El_Salvador" title="Geography of El Salvador">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 21,041 km<sup>2</sup> (8,124 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">148th</a>)</td></tr>
#
# 21,041 km2 (8,124 sq mi) (148th)
# matchObj.group() :21,041
# matchObj.group(0) :21,041
# matchObj.group(1) :21,041
# 21041
# ['gq' 'Equatorial Guinea' nan
#  'https://en.wikipedia.org/wiki/Equatorial_Guinea' 1 100]
# https://en.wikipedia.org/wiki/Equatorial_Guinea
# https://en.wikipedia.org/wiki/Equatorial_Guinea
# [<a href="/wiki/Geography_of_Equatorial_Guinea" title="Geography of Equatorial Guinea">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 28,050 km<sup>2</sup> (10,830 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">141st</a>)</td></tr>
#
# 28,050 km2 (10,830 sq mi) (141st)
# matchObj.group() :28,050
# matchObj.group(0) :28,050
# matchObj.group(1) :28,050
# 28050
# ['ee' 'Estonia' nan 'https://en.wikipedia.org/wiki/Estonia' 1 100]
# https://en.wikipedia.org/wiki/Estonia
# https://en.wikipedia.org/wiki/Estonia
# [<a href="/wiki/Geography_of_Estonia" title="Geography of Estonia">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 45,227<sup class="reference" id="cite_ref-2"><a href="#cite_note-2">[2]</a></sup> km<sup>2</sup> (17,462 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">129th<sup>d</sup></a>)</td></tr>
#
# 45,227[2] km2 (17,462 sq mi) (129thd)
# matchObj.group() :45,227
# matchObj.group(0) :45,227
# matchObj.group(1) :45,227
# 45227
# ['et' 'Ethiopia' nan 'https://en.wikipedia.org/wiki/Ethiopia' 1 100]
# https://en.wikipedia.org/wiki/Ethiopia
# https://en.wikipedia.org/wiki/Ethiopia
# [<a href="/wiki/Geography_of_Ethiopia" title="Geography of Ethiopia">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 1,104,300 km<sup>2</sup> (426,400 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">26th</a>)</td></tr>
#
# 1,104,300 km2 (426,400 sq mi) (26th)
# matchObj.group() :1,104,300
# matchObj.group(0) :1,104,300
# matchObj.group(1) :1,104,300
# 1104300
# ['fo' 'Faroe Islands' nan nan 1 -1]
# ['fm' 'Federated States of Micronesia' nan nan 1 -1]
# ['fj' 'Fiji' nan 'https://en.wikipedia.org/wiki/Fiji' 1 100]
# https://en.wikipedia.org/wiki/Fiji
# https://en.wikipedia.org/wiki/Fiji
# [<a href="/wiki/Geography_of_Fiji" title="Geography of Fiji">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 18,274 km<sup>2</sup> (7,056 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">151st</a>)</td></tr>
#
# 18,274 km2 (7,056 sq mi) (151st)
# matchObj.group() :18,274
# matchObj.group(0) :18,274
# matchObj.group(1) :18,274
# 18274
# ['fi' 'Finland' nan 'https://en.wikipedia.org/wiki/Finland' 1 100]
# https://en.wikipedia.org/wiki/Finland
# https://en.wikipedia.org/wiki/Finland
# [<a href="/wiki/Geography_of_Finland" title="Geography of Finland">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 338,424 km<sup>2</sup> (130,666 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">64th</a>)</td></tr>
#
# 338,424 km2 (130,666 sq mi) (64th)
# matchObj.group() :338,424
# matchObj.group(0) :338,424
# matchObj.group(1) :338,424
# 338424
# ['no_code_former serbia and montenegro' 'Former Serbia and Montenegro' nan
#  nan 1 -1]
# ['no_code_former yugoslavia' 'Former Yugoslavia' nan nan 1 -1]
# ['fr' 'France' nan 'https://en.wikipedia.org/wiki/France' 1 100]
# https://en.wikipedia.org/wiki/France
# https://en.wikipedia.org/wiki/France
# [<a href="/wiki/Geography_of_France" title="Geography of France">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 640,679 km<sup>2</sup> (247,368 sq mi)<wbr/><sup class="reference" id="cite_ref-7"><a href="#cite_note-7">[3]</a></sup> (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">42nd</a>)</td></tr>
#
# 640,679 km2 (247,368 sq mi)[3] (42nd)
# matchObj.group() :640,679
# matchObj.group(0) :640,679
# matchObj.group(1) :640,679
# 640679
# ['gf' 'French Guiana' nan nan 1 -1]
# ['pf' 'French Polynesia' nan nan 1 -1]
# ['ga' 'Gabon' nan 'https://en.wikipedia.org/wiki/Gabon' 1 100]
# https://en.wikipedia.org/wiki/Gabon
# https://en.wikipedia.org/wiki/Gabon
# [<a href="/wiki/Geography_of_Gabon" title="Geography of Gabon">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 267,667 km<sup>2</sup> (103,347 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">76th</a>)</td></tr>
#
# 267,667 km2 (103,347 sq mi) (76th)
# matchObj.group() :267,667
# matchObj.group(0) :267,667
# matchObj.group(1) :267,667
# 267667
# ['gm' 'Gambia' nan nan 1 -1]
# ['ge' 'Georgia' nan 'https://en.wikipedia.org/wiki/Georgia_(country)' 1
#  100]
# https://en.wikipedia.org/wiki/Georgia_(country)
# https://en.wikipedia.org/wiki/Georgia_(country)
# [<a href="/wiki/Geography_of_Georgia_(country)" title="Geography of Georgia (country)">Area </a>]
# <tr class="mergedbottomrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 69,700 km<sup>2</sup> (26,900 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">119th</a>)</td></tr>
#
# 69,700 km2 (26,900 sq mi) (119th)
# matchObj.group() :69,700
# matchObj.group(0) :69,700
# matchObj.group(1) :69,700
# 69700
# ['de' 'Germany' nan 'https://en.wikipedia.org/wiki/Germany' 1 100]
# https://en.wikipedia.org/wiki/Germany
# https://en.wikipedia.org/wiki/Germany
# [<a href="/wiki/Geography_of_Germany" title="Geography of Germany">Area </a>]
# <tr class="mergedbottomrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 357,386 km<sup>2</sup> (137,988 sq mi)<sup class="reference" id="cite_ref-Fläche_8-0"><a href="#cite_note-Fläche-8">[4]</a></sup> (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">62nd</a>)</td></tr>
#
# 357,386 km2 (137,988 sq mi)[4] (62nd)
# matchObj.group() :357,386
# matchObj.group(0) :357,386
# matchObj.group(1) :357,386
# 357386
# ['gh' 'Ghana' nan 'https://en.wikipedia.org/wiki/Ghana' 1 100]
# https://en.wikipedia.org/wiki/Ghana
# https://en.wikipedia.org/wiki/Ghana
# [<a href="/wiki/Geography_of_Ghana" title="Geography of Ghana">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 239,567 km<sup>2</sup> (92,497 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">80th</a>)</td></tr>
#
# 239,567 km2 (92,497 sq mi) (80th)
# matchObj.group() :239,567
# matchObj.group(0) :239,567
# matchObj.group(1) :239,567
# 239567
# ['gi' 'Gibraltar' nan nan 1 -1]
# ['gr' 'Greece' nan 'https://en.wikipedia.org/wiki/Greece' 1 100]
# https://en.wikipedia.org/wiki/Greece
# https://en.wikipedia.org/wiki/Greece
# [<a href="/wiki/Geography_of_Greece" title="Geography of Greece">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 131,957 km<sup>2</sup> (50,949 sq mi)<sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup> (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">95th</a>)</td></tr>
#
# 131,957 km2 (50,949 sq mi)[1] (95th)
# matchObj.group() :131,957
# matchObj.group(0) :131,957
# matchObj.group(1) :131,957
# 131957
# ['gl' 'Greenland' nan nan 1 -1]
# ['gd' 'Grenada' nan 'https://en.wikipedia.org/wiki/Grenada' 1 100]
# https://en.wikipedia.org/wiki/Grenada
# https://en.wikipedia.org/wiki/Grenada
# [<a href="/wiki/Geography_of_Grenada" title="Geography of Grenada">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 348.5 km<sup>2</sup> (134.6 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">185th</a>)</td></tr>
#
# 348.5 km2 (134.6 sq mi) (185th)
# matchObj.group() :348
# matchObj.group(0) :348
# matchObj.group(1) :348
# 348
# ['gp' 'Guadeloupe' nan nan 1 -1]
# ['gu' 'Guam' nan nan 1 -1]
# ['gt' 'Guatemala' nan 'https://en.wikipedia.org/wiki/Guatemala' 1 100]
# https://en.wikipedia.org/wiki/Guatemala
# https://en.wikipedia.org/wiki/Guatemala
# [<a href="/wiki/Geography_of_Guatemala" title="Geography of Guatemala">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 108,889 km<sup>2</sup> (42,042 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">105th</a>)</td></tr>
#
# 108,889 km2 (42,042 sq mi) (105th)
# matchObj.group() :108,889
# matchObj.group(0) :108,889
# matchObj.group(1) :108,889
# 108889
# ['gn' 'Guinea' nan nan 1 -1]
# ['gw' 'Guinea-Bissau' nan 'https://en.wikipedia.org/wiki/Guinea-Bissau' 1
#  100]
# https://en.wikipedia.org/wiki/Guinea-Bissau
# https://en.wikipedia.org/wiki/Guinea-Bissau
# [<a href="/wiki/Geography_of_Guinea-Bissau" title="Geography of Guinea-Bissau">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 36,125 km<sup>2</sup> (13,948 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">134th</a>)</td></tr>
#
# 36,125 km2 (13,948 sq mi) (134th)
# matchObj.group() :36,125
# matchObj.group(0) :36,125
# matchObj.group(1) :36,125
# 36125
# ['gy' 'Guyana' nan 'https://en.wikipedia.org/wiki/Guyana' 1 100]
# https://en.wikipedia.org/wiki/Guyana
# https://en.wikipedia.org/wiki/Guyana
# [<a href="/wiki/Geography_of_Guyana" title="Geography of Guyana">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 214,970 km<sup>2</sup> (83,000 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">83rd</a>)</td></tr>
#
# 214,970 km2 (83,000 sq mi) (83rd)
# matchObj.group() :214,970
# matchObj.group(0) :214,970
# matchObj.group(1) :214,970
# 214970
# ['ht' 'Haiti' nan 'https://en.wikipedia.org/wiki/Haiti' 1 100]
# https://en.wikipedia.org/wiki/Haiti
# https://en.wikipedia.org/wiki/Haiti
# [<a href="/wiki/Geography_of_Haiti" title="Geography of Haiti">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 27,750 km<sup>2</sup> (10,710 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">143rd</a>)</td></tr>
#
# 27,750 km2 (10,710 sq mi) (143rd)
# matchObj.group() :27,750
# matchObj.group(0) :27,750
# matchObj.group(1) :27,750
# 27750
# ['va' 'Holy See (Vatican City State)' nan
#  'https://en.wikipedia.org/wiki/Vatican_City' 1 100]
# https://en.wikipedia.org/wiki/Vatican_City
# https://en.wikipedia.org/wiki/Vatican_City
# [<a href="/wiki/Geography_of_Vatican_City" title="Geography of Vatican City">Area </a>]
# <tr class="mergedbottomrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 0.44 km<sup>2</sup> (0.17 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">196th</a>)</td></tr>
#
# 0.44 km2 (0.17 sq mi) (196th)
# matchObj.group() :0
# matchObj.group(0) :0
# matchObj.group(1) :0
# 0
# ['hn' 'Honduras' nan 'https://en.wikipedia.org/wiki/Honduras' 1 100]
# https://en.wikipedia.org/wiki/Honduras
# https://en.wikipedia.org/wiki/Honduras
# [<a href="/wiki/Geography_of_Honduras" title="Geography of Honduras">Area </a>]
# <tr class="mergedbottomrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 112,492 km<sup>2</sup> (43,433 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">101st</a>)</td></tr>
#
# 112,492 km2 (43,433 sq mi) (101st)
# matchObj.group() :112,492
# matchObj.group(0) :112,492
# matchObj.group(1) :112,492
# 112492
# ['hk' 'Hong Kong' nan nan 1 -1]
# ['hu' 'Hungary' nan 'https://en.wikipedia.org/wiki/Hungary' 1 100]
# https://en.wikipedia.org/wiki/Hungary
# https://en.wikipedia.org/wiki/Hungary
# [<a href="/wiki/Geography_of_Hungary" title="Geography of Hungary">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 93,030<sup class="reference" id="cite_ref-area_7-0"><a href="#cite_note-area-7">[7]</a></sup> km<sup>2</sup> (35,920 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">108th</a>)</td></tr>
#
# 93,030[7] km2 (35,920 sq mi) (108th)
# matchObj.group() :93,030
# matchObj.group(0) :93,030
# matchObj.group(1) :93,030
# 93030
# ['is' 'Iceland' nan nan 1 -1]
# ['in' 'India' nan 'https://en.wikipedia.org/wiki/India' 1 100]
# https://en.wikipedia.org/wiki/India
# https://en.wikipedia.org/wiki/India
# [<a href="/wiki/Geography_of_India" title="Geography of India">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 3,287,263<sup class="reference" id="cite_ref-india.gov.in2_6-1"><a href="#cite_note-india.gov.in2-6">[5]</a></sup> km<sup>2</sup> (1,269,219 sq mi)<sup class="reference" id="cite_ref-16"><a href="#cite_note-16">[d]</a></sup> (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">7th</a>)</td></tr>
#
# 3,287,263[5] km2 (1,269,219 sq mi)[d] (7th)
# matchObj.group() :3,287,263
# matchObj.group(0) :3,287,263
# matchObj.group(1) :3,287,263
# 3287263
# ['id' 'Indonesia' nan 'https://en.wikipedia.org/wiki/Indonesia' 1 100]
# https://en.wikipedia.org/wiki/Indonesia
# https://en.wikipedia.org/wiki/Indonesia
# [<a href="/wiki/Geography_of_Indonesia" title="Geography of Indonesia">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• <a class="mw-redirect" href="/wiki/Land_area" title="Land area">Land</a></div></th><td>
# 1,904,569<sup class="reference" id="cite_ref-6"><a href="#cite_note-6">[6]</a></sup> km<sup>2</sup> (735,358 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">14th</a>)</td></tr>
#
# 1,904,569[6] km2 (735,358 sq mi) (14th)
# matchObj.group() :1,904,569
# matchObj.group(0) :1,904,569
# matchObj.group(1) :1,904,569
# 1904569
# ['ir' 'Iran, Islamic Republic of' nan 'https://en.wikipedia.org/wiki/Iran'
#  1 100]
# https://en.wikipedia.org/wiki/Iran
# https://en.wikipedia.org/wiki/Iran
# [<a href="/wiki/Geography_of_Iran" title="Geography of Iran">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 1,648,195 km<sup>2</sup> (636,372 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">17th</a>)</td></tr>
#
# 1,648,195 km2 (636,372 sq mi) (17th)
# matchObj.group() :1,648,195
# matchObj.group(0) :1,648,195
# matchObj.group(1) :1,648,195
# 1648195
# ['iq' 'Iraq' nan 'https://en.wikipedia.org/wiki/Iraq' 1 100]
# https://en.wikipedia.org/wiki/Iraq
# https://en.wikipedia.org/wiki/Iraq
# [<a href="/wiki/Geography_of_Iraq" title="Geography of Iraq">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 437,072 km<sup>2</sup> (168,754 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">58th</a>)</td></tr>
#
# 437,072 km2 (168,754 sq mi) (58th)
# matchObj.group() :437,072
# matchObj.group(0) :437,072
# matchObj.group(1) :437,072
# 437072
# ['ie' 'Ireland' nan nan 1 -1]
# ['il' 'Israel' nan 'https://en.wikipedia.org/wiki/Israel' 1 100]
# https://en.wikipedia.org/wiki/Israel
# https://en.wikipedia.org/wiki/Israel
# [<a href="/wiki/Geography_of_Israel" title="Geography of Israel">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 20,770–22,072 km<sup>2</sup> (8,019–8,522 sq mi)<sup class="reference" id="ref_area"><a href="#endnote_area">[a]</a></sup> (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">150th</a>)</td></tr>
#
# 20,770–22,072 km2 (8,019–8,522 sq mi)[a] (150th)
# matchObj.group() :20,770
# matchObj.group(0) :20,770
# matchObj.group(1) :20,770
# 20770
# ['it' 'Italy' nan 'https://en.wikipedia.org/wiki/Italy' 1 100]
# https://en.wikipedia.org/wiki/Italy
# https://en.wikipedia.org/wiki/Italy
# [<a href="/wiki/Geography_of_Italy" title="Geography of Italy">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 301,340 km<sup>2</sup> (116,350 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">71st</a>)</td></tr>
#
# 301,340 km2 (116,350 sq mi) (71st)
# matchObj.group() :301,340
# matchObj.group(0) :301,340
# matchObj.group(1) :301,340
# 301340
# ['jm' 'Jamaica' nan 'https://en.wikipedia.org/wiki/Jamaica' 1 100]
# https://en.wikipedia.org/wiki/Jamaica
# https://en.wikipedia.org/wiki/Jamaica
# [<a href="/wiki/Geography_of_Jamaica" title="Geography of Jamaica">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 10,991 km<sup>2</sup> (4,244 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">160th</a>)</td></tr>
#
# 10,991 km2 (4,244 sq mi) (160th)
# matchObj.group() :10,991
# matchObj.group(0) :10,991
# matchObj.group(1) :10,991
# 10991
# ['jp' 'Japan' nan 'https://en.wikipedia.org/wiki/Japan' 1 100]
# https://en.wikipedia.org/wiki/Japan
# https://en.wikipedia.org/wiki/Japan
# [<a href="/wiki/Geography_of_Japan" title="Geography of Japan">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# ...
#
# 1,886,068 km2 (728,215 sq mi) (15th)
# matchObj.group() :1,886,068
# matchObj.group(0) :1,886,068
# matchObj.group(1) :1,886,068
# 1886068
# ['sr' 'Suriname' nan 'https://en.wikipedia.org/wiki/Suriname' 1 100]
# https://en.wikipedia.org/wiki/Suriname
# https://en.wikipedia.org/wiki/Suriname
# [<a href="/wiki/Geography_of_Suriname" title="Geography of Suriname">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 163,821 km<sup>2</sup> (63,252 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">90th</a>)</td></tr>
#
# 163,821 km2 (63,252 sq mi) (90th)
# matchObj.group() :163,821
# matchObj.group(0) :163,821
# matchObj.group(1) :163,821
# 163821
# ['sz' 'Swaziland' nan nan 1 -1]
# ['se' 'Sweden' nan 'https://en.wikipedia.org/wiki/Sweden' 1 100]
# https://en.wikipedia.org/wiki/Sweden
# https://en.wikipedia.org/wiki/Sweden
# [<a href="/wiki/Geography_of_Sweden" title="Geography of Sweden">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 450,295 km<sup>2</sup> (173,860 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">55th</a>)</td></tr>
#
# 450,295 km2 (173,860 sq mi) (55th)
# matchObj.group() :450,295
# matchObj.group(0) :450,295
# matchObj.group(1) :450,295
# 450295
# ['ch' 'Switzerland' nan 'https://en.wikipedia.org/wiki/Switzerland' 1 100]
# https://en.wikipedia.org/wiki/Switzerland
# https://en.wikipedia.org/wiki/Switzerland
# [<a href="/wiki/Geography_of_Switzerland" title="Geography of Switzerland">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 41,285 km<sup>2</sup> (15,940 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">132nd</a>)</td></tr>
#
# 41,285 km2 (15,940 sq mi) (132nd)
# matchObj.group() :41,285
# matchObj.group(0) :41,285
# matchObj.group(1) :41,285
# 41285
# ['sy' 'Syrian Arab Republic' nan 'https://en.wikipedia.org/wiki/Syria' 1
#  100]
# https://en.wikipedia.org/wiki/Syria
# https://en.wikipedia.org/wiki/Syria
# [<a href="/wiki/Geography_of_Syria" title="Geography of Syria">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 185,180<sup class="reference" id="cite_ref-3"><a href="#cite_note-3">[3]</a></sup> km<sup>2</sup> (71,500 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">87th</a>)</td></tr>
#
# 185,180[3] km2 (71,500 sq mi) (87th)
# matchObj.group() :185,180
# matchObj.group(0) :185,180
# matchObj.group(1) :185,180
# 185180
# ['tw' 'Taiwan' nan nan 1 -1]
# ['tj' 'Tajikistan' nan 'https://en.wikipedia.org/wiki/Tajikistan' 1 100]
# https://en.wikipedia.org/wiki/Tajikistan
# https://en.wikipedia.org/wiki/Tajikistan
# [<a href="/wiki/Geography_of_Tajikistan" title="Geography of Tajikistan">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 143,100 km<sup>2</sup> (55,300 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">94th</a>)</td></tr>
#
# 143,100 km2 (55,300 sq mi) (94th)
# matchObj.group() :143,100
# matchObj.group(0) :143,100
# matchObj.group(1) :143,100
# 143100
# ['tz' 'Tanzania' nan 'https://en.wikipedia.org/wiki/Tanzania' 1 100]
# https://en.wikipedia.org/wiki/Tanzania
# https://en.wikipedia.org/wiki/Tanzania
# [<a href="/wiki/Geography_of_Tanzania" title="Geography of Tanzania">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 947,303 km<sup>2</sup> (365,756 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">31st</a>)</td></tr>
#
# 947,303 km2 (365,756 sq mi) (31st)
# matchObj.group() :947,303
# matchObj.group(0) :947,303
# matchObj.group(1) :947,303
# 947303
# ['th' 'Thailand' nan 'https://en.wikipedia.org/wiki/Thailand' 1 100]
# https://en.wikipedia.org/wiki/Thailand
# https://en.wikipedia.org/wiki/Thailand
# [<a href="/wiki/Geography_of_Thailand" title="Geography of Thailand">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 513,120 km<sup>2</sup> (198,120 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">50th</a>)</td></tr>
#
# 513,120 km2 (198,120 sq mi) (50th)
# matchObj.group() :513,120
# matchObj.group(0) :513,120
# matchObj.group(1) :513,120
# 513120
# ['tg' 'Togo' nan 'https://en.wikipedia.org/wiki/Togo' 1 100]
# https://en.wikipedia.org/wiki/Togo
# https://en.wikipedia.org/wiki/Togo
# [<a href="/wiki/Geography_of_Togo" title="Geography of Togo">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 56,785 km<sup>2</sup> (21,925 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">123rd</a>)</td></tr>
#
# 56,785 km2 (21,925 sq mi) (123rd)
# matchObj.group() :56,785
# matchObj.group(0) :56,785
# matchObj.group(1) :56,785
# 56785
# ['tt' 'Trinidad and Tobago' nan
#  'https://en.wikipedia.org/wiki/Trinidad_and_Tobago' 1 100]
# https://en.wikipedia.org/wiki/Trinidad_and_Tobago
# https://en.wikipedia.org/wiki/Trinidad_and_Tobago
# [<a href="/wiki/Geography_of_Trinidad_and_Tobago" title="Geography of Trinidad and Tobago">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 5,131 km<sup>2</sup> (1,981 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">165th</a>)</td></tr>
#
# 5,131 km2 (1,981 sq mi) (165th)
# matchObj.group() :5,131
# matchObj.group(0) :5,131
# matchObj.group(1) :5,131
# 5131
# ['tn' 'Tunisia' nan 'https://en.wikipedia.org/wiki/Tunisia' 1 100]
# https://en.wikipedia.org/wiki/Tunisia
# https://en.wikipedia.org/wiki/Tunisia
# [<a href="/wiki/Geography_of_Tunisia" title="Geography of Tunisia">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 163,610 km<sup>2</sup> (63,170 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">91st</a>)</td></tr>
#
# 163,610 km2 (63,170 sq mi) (91st)
# matchObj.group() :163,610
# matchObj.group(0) :163,610
# matchObj.group(1) :163,610
# 163610
# ['tr' 'Turkey' nan 'https://en.wikipedia.org/wiki/Turkey' 1 100]
# https://en.wikipedia.org/wiki/Turkey
# https://en.wikipedia.org/wiki/Turkey
# [<a href="/wiki/Geography_of_Turkey" title="Geography of Turkey">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 783,356 km<sup>2</sup> (302,455 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">36th</a>)</td></tr>
#
# 783,356 km2 (302,455 sq mi) (36th)
# matchObj.group() :783,356
# matchObj.group(0) :783,356
# matchObj.group(1) :783,356
# 783356
# ['ug' 'Uganda' nan 'https://en.wikipedia.org/wiki/Uganda' 1 100]
# https://en.wikipedia.org/wiki/Uganda
# https://en.wikipedia.org/wiki/Uganda
# [<a href="/wiki/Geography_of_Uganda" title="Geography of Uganda">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 241,038 km<sup>2</sup> (93,065 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">79th</a>)</td></tr>
#
# 241,038 km2 (93,065 sq mi) (79th)
# matchObj.group() :241,038
# matchObj.group(0) :241,038
# matchObj.group(1) :241,038
# 241038
# ['ua' 'Ukraine' nan 'https://en.wikipedia.org/wiki/Ukraine' 1 100]
# https://en.wikipedia.org/wiki/Ukraine
# https://en.wikipedia.org/wiki/Ukraine
# [<a href="/wiki/Geography_of_Ukraine" title="Geography of Ukraine">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 603,628 km<sup>2</sup> (233,062 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">45th</a>)</td></tr>
#
# 603,628 km2 (233,062 sq mi) (45th)
# matchObj.group() :603,628
# matchObj.group(0) :603,628
# matchObj.group(1) :603,628
# 603628
# ['ae' 'United Arab Emirates' nan
#  'https://en.wikipedia.org/wiki/United_Arab_Emirates' 1 100]
# https://en.wikipedia.org/wiki/United_Arab_Emirates
# https://en.wikipedia.org/wiki/United_Arab_Emirates
# None
# ['gb' 'United Kingdom' nan 'https://en.wikipedia.org/wiki/United_Kingdom'
#  1 100]
# https://en.wikipedia.org/wiki/United_Kingdom
# https://en.wikipedia.org/wiki/United_Kingdom
# [<a href="/wiki/Geography_of_the_United_Kingdom" title="Geography of the United Kingdom">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 242,495 km<sup>2</sup> (93,628 sq mi)<sup class="reference" id="cite_ref-12"><a href="#cite_note-12">[8]</a></sup> (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">78th</a>)</td></tr>
#
# 242,495 km2 (93,628 sq mi)[8] (78th)
# matchObj.group() :242,495
# matchObj.group(0) :242,495
# matchObj.group(1) :242,495
# 242495
# ['us' 'United States of America' nan
#  'https://en.wikipedia.org/wiki/United_States' 1 100]
# https://en.wikipedia.org/wiki/United_States
# https://en.wikipedia.org/wiki/United_States
# [<a href="/wiki/Geography_of_the_United_States" title="Geography of the United States">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total area</div></th><td>
# 3,796,742 sq mi (9,833,520 km<sup>2</sup>)<sup class="reference" id="cite_ref-11"><a href="#cite_note-11">[8]</a></sup> (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">3rd/4th</a>)</td></tr>
#
# 3,796,742 sq mi (9,833,520 km2)[8] (3rd/4th)
# matchObj.group() :3,796,742
# matchObj.group(0) :3,796,742
# matchObj.group(1) :3,796,742
# 3796742
# ['uy' 'Uruguay' nan 'https://en.wikipedia.org/wiki/Uruguay' 1 100]
# https://en.wikipedia.org/wiki/Uruguay
# https://en.wikipedia.org/wiki/Uruguay
# [<a href="/wiki/Geography_of_Uruguay" title="Geography of Uruguay">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 176,215 km<sup>2</sup> (68,037 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">89th</a>)</td></tr>
#
# 176,215 km2 (68,037 sq mi) (89th)
# matchObj.group() :176,215
# matchObj.group(0) :176,215
# matchObj.group(1) :176,215
# 176215
# ['uz' 'Uzbekistan' nan 'https://en.wikipedia.org/wiki/Uzbekistan' 1 100]
# https://en.wikipedia.org/wiki/Uzbekistan
# https://en.wikipedia.org/wiki/Uzbekistan
# [<a href="/wiki/Geography_of_Uzbekistan" title="Geography of Uzbekistan">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 448,978 km<sup>2</sup> (173,351 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">56th</a>)</td></tr>
#
# 448,978 km2 (173,351 sq mi) (56th)
# matchObj.group() :448,978
# matchObj.group(0) :448,978
# matchObj.group(1) :448,978
# 448978
# ['vu' 'Vanuatu' nan 'https://en.wikipedia.org/wiki/Vanuatu' 1 100]
# https://en.wikipedia.org/wiki/Vanuatu
# https://en.wikipedia.org/wiki/Vanuatu
# [<a href="/wiki/Geography_of_Vanuatu" title="Geography of Vanuatu">Area </a>]
# <tr class="mergedbottomrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 12,189 km<sup>2</sup> (4,706 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">157th</a>)</td></tr>
#
# 12,189 km2 (4,706 sq mi) (157th)
# matchObj.group() :12,189
# matchObj.group(0) :12,189
# matchObj.group(1) :12,189
# 12189
# ['ve' 'Venezuela' nan nan 1 -1]
# ['vn' 'Vietnam' nan 'https://en.wikipedia.org/wiki/Venezuela' 1 100]
# https://en.wikipedia.org/wiki/Venezuela
# https://en.wikipedia.org/wiki/Venezuela
# [<a href="/wiki/Geography_of_Venezuela" title="Geography of Venezuela">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 916,445 km<sup>2</sup> (353,841 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">32nd</a>)</td></tr>
#
# 916,445 km2 (353,841 sq mi) (32nd)
# matchObj.group() :916,445
# matchObj.group(0) :916,445
# matchObj.group(1) :916,445
# 916445
# ['vi' 'Virgin Islands (U.S.)' nan 'https://en.wikipedia.org/wiki/Vietnam'
#  1 100]
# https://en.wikipedia.org/wiki/Vietnam
# https://en.wikipedia.org/wiki/Vietnam
# [<a href="/wiki/Geography_of_Vietnam" title="Geography of Vietnam">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 331,212<sup class="reference" id="cite_ref-area_8-0"><a href="#cite_note-area-8">[n 4]</a></sup> km<sup>2</sup> (127,882 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">65th</a>)</td></tr>
#
# 331,212[n 4] km2 (127,882 sq mi) (65th)
# matchObj.group() :331,212
# matchObj.group(0) :331,212
# matchObj.group(1) :331,212
# 331212
# ['ye' 'Yemen' nan 'https://en.wikipedia.org/wiki/Yemen' 1 100]
# https://en.wikipedia.org/wiki/Yemen
# https://en.wikipedia.org/wiki/Yemen
# [<a href="/wiki/Geography_of_Yemen" title="Geography of Yemen">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 527,968 km<sup>2</sup> (203,850 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">49th</a>)</td></tr>
#
# 527,968 km2 (203,850 sq mi) (49th)
# matchObj.group() :527,968
# matchObj.group(0) :527,968
# matchObj.group(1) :527,968
# 527968
# ['zm' 'Zambia' nan 'https://en.wikipedia.org/wiki/Zambia' 1 100]
# https://en.wikipedia.org/wiki/Zambia
# https://en.wikipedia.org/wiki/Zambia
# [<a href="/wiki/Geography_of_Zambia" title="Geography of Zambia">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 752,618 km<sup>2</sup> (290,587 sq mi)<sup class="reference" id="cite_ref-area_2-0"><a href="#cite_note-area-2">[2]</a></sup> (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">38th</a>)</td></tr>
#
# 752,618 km2 (290,587 sq mi)[2] (38th)
# matchObj.group() :752,618
# matchObj.group(0) :752,618
# matchObj.group(1) :752,618
# 752618
# ['zw' 'Zimbabwe' nan 'https://en.wikipedia.org/wiki/Zimbabwe' 1 100]
# https://en.wikipedia.org/wiki/Zimbabwe
# https://en.wikipedia.org/wiki/Zimbabwe
# [<a href="/wiki/Geography_of_Zimbabwe" title="Geography of Zimbabwe">Area </a>]
# <tr class="mergedrow"><th scope="row"><div style="text-indent:-0.9em;margin-left:1.2em;font-weight:normal;">• Total</div></th><td>
# 390,757 km<sup>2</sup> (150,872 sq mi) (<a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">60th</a>)</td></tr>
#
# 390,757 km2 (150,872 sq mi) (60th)
# matchObj.group() :390,757
# matchObj.group(0) :390,757
# matchObj.group(1) :390,757
# 390757

# %%
i=0
while i<len(result_areas_array):
    if type(result_areas_array[i]) is None:
        result_areas_array[i] = -1
        
for 
area in result_areas_array:
# Out:
# [-1, 652864, 28748, 2381741, -1, 467, 1246700, -1, 29743, -1, 7692024, 83879, 86600, -1, 765, 147570, 439, 207595, 30528, 22966, 114763, -1, 38394, 1098581, 51129, 581730, 8515767, 5765, 110993, 274200, 27834, 181035, 475442, -1, -1, 622984, 1284000, 756096, -1, 1141748, 1862, -1, 51100, 56594, 109884, 9251, -1, -1, 42933, 23200, None, 283561, 1010408, 21041, 28050, 45227, 1104300, -1, -1, 18274, 338424, -1, -1, 640679, -1, -1, 267667, -1, 69700, 357386, 239567, -1, 131957, -1, 348, -1, -1, 108889, -1, 36125, 214970, 27750, 0, 112492, -1, 93030, -1, 3287263, 1904569, 1648195, 437072, -1, 20770, 301340, 10991, 377973, -1, 89342, 2724900, 580367, 120540, 100363, -1, 17818, 199951, 237955, 64589, 10452, 30355, 111369, None, 160, 65300, 2586, 25713, 587041, 118484, 330803, 298, None, 316, -1, 1030000, 2040, -1, 1972550, 33846, 2, 1566000, 13812, -1, 710850, 801590, -1, 825615, 147181, 42508, -1, -1, 268021, 130375, 1267000, 923768, -1, 385203, 309500, 881913, 459, 6020, -1, 75417, 462840, 406752, 1285216, 300000, 312696, 92212, -1, 11581, 238397, 17098246, 26338, -1, 261, 2149690, 196712, 88361, 459, 71740, 722, 49035, 20273, 28400, 1221037, 505990, -1, 1886068, 163821, -1, 450295, 41285, 185180, -1, 143100, 947303, 513120, 56785, 5131, 163610, 783356, 241038, 603628, None, 242495, 3796742, 176215, 448978, 12189, -1, 916445, 331212, 527968, 752618, 390757]

# %%
# countries_codes["area"]=np.array(result_areas_array).astype(int)
# countries_codes.head()
# countries_codes.loc[countries_codes.full_country_name == "Qatar"].head()
countries_codes.loc[countries_codes.area.isnull()].head()
# Out:
#     iso2       full_country_name  comment  \
# 50    do      Dominican Republic      NaN
# 110   ly  Libyan Arab Jamahiriya      NaN
# 119   ml                    Mali      NaN
# 192   ae    United Arab Emirates      NaN
#
#                                              wiki_link  population  area
# 50    https://en.wikipedia.org/wiki/Dominican_Republic           1   NaN
# 110                https://en.wikipedia.org/wiki/Libya           1   NaN
# 119                 https://en.wikipedia.org/wiki/Mali           1   NaN
# 192  https://en.wikipedia.org/wiki/United_Arab_Emir...           1   NaN

# %%
countries_codes.to_csv(r"c:\Dev\05. Jupyter\2. FDA countries clean\csv\countries_codes_area_1Nov.csv")
